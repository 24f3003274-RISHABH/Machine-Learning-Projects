# %% [markdown]
# <a href="https://colab.research.google.com/github/24f3003274-RISHABH/IITMBS_ML_DL_GEN_AI/blob/main/MLP/MLP_GA_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
