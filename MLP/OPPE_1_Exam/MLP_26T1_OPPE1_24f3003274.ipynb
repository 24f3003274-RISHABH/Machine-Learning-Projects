# %% [markdown]
# # MLP 2026 Term 1 OPPE 1
# **Date:** 4th April 2026

# %%
# @title Student's Details to be filled before the exam starts: {"run":"auto","vertical-output":true,"form-width":"100%","display-mode":"form"}

Student_Name = "Rishabh Keshari" # @param {type:"string"}
Student_Roll_No = "24f3003274" # @param {type:"string"}

try:
  if len(Student_Name) == 0:
    raise ValueError("Warning:  Please write your name")
  elif len(Student_Roll_No)==0:
    raise ValueError("Warning: Please write your roll number")

  else:
    print(f"Best Of Luck {Student_Name}({Student_Roll_No})")

except ValueError as e:
  print(e)
# Out:
# Best Of Luck Rishabh Keshari(24f3003274)

# %% [markdown]
# # Unit 1 of 2: Preprocessing

# %% [markdown]
# ### Q. 1:

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('D:\PROJECTS\IITMBS_ML_DL_GEN_AI\MLP\OPPE_1_Exam\preprocessing_v3 (1).csv')
df
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# <>:3: SyntaxWarning: invalid escape sequence '\P'
# C:\Users\hp\AppData\Local\Temp\ipykernel_167120\1901285710.py:3: SyntaxWarning: invalid escape sequence '\P'
#   df=pd.read_csv('D:\PROJECTS\IITMBS_ML_DL_GEN_AI\MLP\OPPE_1_Exam\preprocessing_v3 (1).csv')
#       engine_size  horsepower       mileage       age       weight  brand  \
# 0        2.169719  112.545926  52464.057543  8.365402  1577.006291    NaN
# 1        2.058949  127.903579  50856.101146  3.958309  1576.965234    NaN
# 2        1.972820         NaN  55512.772677  4.509092  1475.939436  Honda
# 3        2.806696  127.008348  48321.573990  2.048559  1195.060469   Ford
# 4        1.358985  110.713135  52531.710991  4.818182  2055.235343    NaN
# ...           ...         ...           ...       ...          ...    ...
# 8995     2.954302         NaN  55876.178776  6.472577  1605.484983  Honda
# 8996     1.409928  200.854215  16787.773634  4.159017  1618.521639  Honda
# ...

# %% [markdown]
# ### Q. 2:

# %%
print(df.shape)
k=df['horsepower'].isnull().sum()
print(k)
l=df['brand'].isnull().sum()
print(l)
remain=9000-l
print(remain)
ratio=k/remain
print(ratio)
# Out:
# (9000, 8)
# 2695
# 2758
# 6242
# 0.4317526433835309

# %% [markdown]
# ### Q. 3:

# %%
import seaborn as sns
sns.histplot(df['price'], bins=30, kde=True)
# Out:
# <Axes: xlabel='price', ylabel='Count'>

# %%
sns.heatmap(df[['price']])
# Out:
# <Axes: >

# %%
sns.kdeplot(df['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_df = df.select_dtypes(include=['float64', 'int64'])

# Compute correlation
corr = numeric_df.corr()

# Plot heatmap
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# ### Q. 4:

# %% [markdown]
# ### Q. 5:

# %%
df.isnull().sum()
petrol=df[(df['fuel_type']=='Petrol')]
petrol.describe().T
# Out:
#               count          mean           std           min           25%  \
# engine_size  2058.0      2.008404      0.512707      0.402064      1.653538
# horsepower   2054.0    149.238132     40.564166     23.569236    121.714262
# mileage      2943.0  59672.072610  19727.329740 -19437.080184  46094.191163
# age          2943.0      4.986222      1.941013     -1.970155      3.617638
# weight       2943.0   1504.186210    295.774990    620.561390   1298.802969
# price        2943.0  29288.154800   6060.251871   5094.812475  25285.285281
#
#                       50%           75%            max
# engine_size      2.011381      2.359357       3.634709
# horsepower     148.887729    177.572108     328.220963
# mileage      59743.360058  72949.895292  125139.338703
# age              5.034270      6.321253      10.786586
# weight        1507.802980   1707.662074    2573.356648
# price        29336.124378  33292.944127   52255.423720

# %%
diesel=df[(df['fuel_type']=='Diesel')]
diesel.describe().T
# Out:
#               count          mean           std           min           25%  \
# engine_size  2116.0      2.001202      0.491805      0.036681      1.672698
# horsepower   2172.0    149.708344     39.896201      7.172075    123.676724
# mileage      3078.0  59618.662744  20082.647799  -3911.390520  45690.747770
# age          3078.0      4.983660      2.004680     -1.498787      3.642465
# weight       3078.0   1506.808995    298.120165    245.657351   1305.799397
# price        3078.0  30512.488421   6091.522556  10768.607443  26337.629424
#
#                       50%           75%            max
# engine_size      2.002256      2.337717       3.682566
# horsepower     149.603837    176.835309     296.288477
# mileage      59704.335824  73136.498549  129018.896085
# age              4.982856      6.345984      12.299865
# weight        1497.755092   1705.872329    2628.885035
# price        30565.090708  34671.404920   53313.553278

# %%
h=abs(1506.808995-1504.186210)
h
# Out:
# 2.6227850000000217

# %%
# 5

g=df[((df['fuel_type']=='Diesel') | (df['fuel_type']=='Hybrid')) & (df['horsepower']!=np.nan) & ]

# %%
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8995    False
# 8996    False
# 8997    False
# 8998    False
# 8999    False
# Name: horsepower, Length: 9000, dtype: bool

# %% [markdown]
# ### Q. 6:

# %%
print(df.dtypes)
# Out:
# engine_size    float64
# horsepower     float64
# mileage        float64
# age            float64
# weight         float64
# brand           object
# fuel_type       object
# price          float64
# dtype: object

# %%
# ● engine_size
# ● weight
# ● age
# ● mileage
# # ● Horsepower
df['engine_size']=df['engine_size'].fillna(df['engine_size'].mean())
df['weight']=df['weight'].fillna(df['weight'].mean())
df['age']=df['age'].fillna(df['age'].mean())
df['horsepower']=df['horsepower'].fillna(df['horsepower'].mean())
df['mileage']=df['mileage'].fillna(df[''])

# %% [markdown]
# ### Q. 7:

# %% [markdown]
# ### Q. 8:

# %% [markdown]
# ### Q. 9:

# %% [markdown]
# ### Q. 10:

# %% [markdown]
# # Unit 2 of 2: Model Building
#
# # Please regularly save your Answers in the exam portal by clicking on "Submit" button

# %% [markdown]
# ### Q.1:

# %%
df
# Out:
#        engine_size  horsepower   mileage       age    weight  fuel_type  \
# 0    -1.324771e+00   -0.404227  0.349983  0.534264  0.509502        2.0
# 1    -1.164363e-15    2.128306  0.567084  0.578260  0.574271        2.0
# 2     4.933420e-01   -1.681097  0.620795  0.638698  0.349978        1.0
# 3     7.006142e-01   -0.476661  0.366338  0.644227  0.662146        1.0
# 4    -1.164363e-15    0.000000  0.569812  0.463527  0.446840        2.0
# ...            ...         ...       ...       ...       ...        ...
# 8995 -1.164363e-15   -4.196609  0.558305  0.610588  0.813598        0.0
# 8996 -2.319422e+00    2.633913  0.655083  0.564562  0.566558        2.0
# 8997 -1.885560e-01    0.000000  0.423530  0.462886  0.294847        0.0
# 8998 -1.164363e-15   -1.304050  0.482060  0.447611  0.431737        2.0
# 8999 -1.060387e+00   -0.720548  0.476069  0.403944  0.420825        2.0
#
#       brand_BMW  brand_Ford  brand_Honda  brand_Toyota         price
# ...

# %% [markdown]
# ### Q. 2:

# %%
df=pd.read_csv('/content/Model_Building_v1.csv')
X=df.drop('price',axis=1)
y=df['price']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
from sklearn.linear_model import Ridge
ridge=Ridge(alpha=0.02)
model=ridge.fit(X_train,y_train)
y_pred=model.predict(X_test)
model.coef_
# Out:
# array([  1607.58015696,   3350.83113487,  -6815.68679704, -10163.6235528 ,
#          4410.22586393,   1275.84618812,   3005.38911593,  -1558.43358411,
#          -525.60821589,   -921.34731645])

# %% [markdown]
# ### Q. 3:

# %% [markdown]
# ### Q. 4:

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import SGDRegressor
sgd=SGDRegressor(
    loss="squared_error",
    penalty="l2",
    alpha=0.0005,
    max_iter=2000,
    learning_rate="adaptive",
    random_state=0
)
model.fit(X_train,y_train)
y_pred=model.predict(X_test)
rmse=np.sqrt(mean_squared_error(y_test,y_pred))
rmse
# Out:
# np.float64(3043.046746762666)

# %% [markdown]
# ### Q. 5:

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.

# %% [markdown]
# ### Q. 6:

# %% [markdown]
# ### Q. 7:

# %% [markdown]
# ### Q. 8:

# %% [markdown]
# ### Q. 9:

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor(random_state=0)
param={
    "n_estimators" :[50, 100,150],

    "learning_rate":[0.0001, 0.001]
}
from sklearn.model_selection import GridSearchCV

grid=GridSearchCV(
    gbr,
    param_grid=param,
    cv=5,
    scoring='neg_mean_squared_error'
)

# %%
grid.fit(X_train,y_train)
# grid.best_params_
# Out:
# {'learning_rate': 0.001, 'n_estimators': 150}

# %% [markdown]
# ### Q. 10:

# %%
from sklearn.neural_network import MLPRegressor
mlp=MLPRegressor(random_state=0,
                 hidden_layer_sizes=[50,32,16],
                 activation ='tanh',
                 solver='lbfgs',

                 )
model=mlp.fit(X_train,y_train)
y_pred=model.predict(X_test)
mse=mean_squared_error(y_test,y_pred)
mse
# Out:
# 29706128.72441551

# %%
# ?MLPRegressor

# %% [markdown]
# ### Q. 11:

# %%
from sklearn.neighbors import KneighborsRegressor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /tmp/ipykernel_1031/2259232199.py in <cell line: 0>()
# ----> 1 from sklearn.neighbors import KneighborsRegressor
#
# ImportError: cannot import name 'KneighborsRegressor' from 'sklearn.neighbors' (/usr/local/lib/python3.12/dist-packages/sklearn/neighbors/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
