# %%
import pandas as pd
df=pd.read_csv('NPPE1_Preprocessing1.csv')

# %%
df.shape
# Out:
# (4000, 14)

# %%
df.head()
# Out:
#         CRIM         ZN      INDUS  POLINDEX   RM   AGE        DIS  \
# 0   1.026769   1.429034   7.851300  1.134216  6.0  42.0   5.251911
# 1   0.848089   0.255543   6.263434  1.245993  7.0  63.0   4.305546
# 2  10.925905   0.441022  18.322960  2.824833  8.0  -2.0   2.409495
# 3   0.559027   1.041175  11.114920  0.794952  6.0   9.0   6.898669
# 4   0.905063  81.167963   3.673369  1.029030  8.0  20.0  10.246463
#
#    HIGHWAYCOUNT         TAX    PTRATIO         IMM        BPL      PRICE  \
# 0             5  279.201277  20.689586  398.811960  10.461456  22.991633
# 1             8  307.444529  17.465398  377.153649  11.619690  24.551055
# 2            25  666.492973  20.351601  387.061355  19.366070  15.875346
# 3             4  305.514181  19.787314  391.778647   6.206820  23.007756
# 4             1  315.913960  17.360439  395.833166  10.827105  21.503177
#
#   RIVERSIDE
# 0        NO
# 1        NO
# 2        NO
# 3        NO
# 4        NO

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'POLINDEX', 'RM', 'AGE', 'DIS', 'HIGHWAYCOUNT',
#        'TAX', 'PTRATIO', 'IMM', 'BPL', 'PRICE', 'RIVERSIDE'],
#       dtype='object')

# %%
df['PRICE'].describe()
# Out:
# count    4000.000000
# mean       24.355923
# std         8.633523
# min         6.348266
# 25%        19.259094
# 50%        22.634566
# 75%        26.947036
# max        53.090256
# Name: PRICE, dtype: float64

# %%
df['PRICE'].mean()
# Out:
# np.float64(24.355923220694248)

# %%
g=df[(df['RM']>=5)]
g['RM'].count()
# Out:
# np.int64(3953)

# %%
# g=df['PRICE'].ASCENDING()

# %%
df.isnull().sum()
# Out:
# CRIM            0
# ZN              0
# INDUS           0
# POLINDEX        0
# RM              0
# AGE             0
# DIS             0
# HIGHWAYCOUNT    0
# TAX             0
# PTRATIO         0
# IMM             0
# BPL             0
# PRICE           0
# RIVERSIDE       0
# dtype: int64

# %%
room=df[(df['RM']==-1)]
room['RM'].count()
# Out:
# np.int64(40)

# %%
neg=df[(df['AGE']<0)]
neg['AGE'].count()
# Out:
# np.int64(50)

# %%
df['AGE'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['RIVERSIDE'].unique()
# Out:
# array(['NO', 'UNKNOWN', 'YES'], dtype=object)

# %%
riverside=df[(df['RIVERSIDE']=='UNKNOWN')]
riverside['RIVERSIDE'].count()
# Out:
# np.int64(88)

# %%
river=df[(df['RIVERSIDE']=='YES') &  (df['AGE']<=50) & (df['AGE']>0) & (df['RIVERSIDE']!='UNKNOWN')]
river[['RIVERSIDE','AGE']].count()
# Out:
# RIVERSIDE    44
# AGE          44
# dtype: int64

# %%
df
# Out:
#            CRIM         ZN      INDUS  POLINDEX   RM    AGE        DIS  \
# 0      1.026769   1.429034   7.851300  1.134216  6.0   42.0   5.251911
# 1      0.848089   0.255543   6.263434  1.245993  7.0   63.0   4.305546
# 2     10.925905   0.441022  18.322960  2.824833  8.0   -2.0   2.409495
# 3      0.559027   1.041175  11.114920  0.794952  6.0    9.0   6.898669
# 4      0.905063  81.167963   3.673369  1.029030  8.0   20.0  10.246463
# ...         ...        ...        ...       ...  ...    ...        ...
# 3995   4.366543   1.159592  22.230240  1.146936  6.0   96.0   2.332414
# 3996   9.132894   0.294115  18.741019  0.876901  6.0  100.0   2.509486
# 3997   0.859468  21.201881   4.098201  1.142168  7.0  102.0   2.187747
# 3998   0.587681  45.399856   3.706238  1.719303  8.0   22.0   7.631113
# 3999   5.143827   0.000920  18.599543  0.864198  7.0   89.0   3.720523
#
#       HIGHWAYCOUNT         TAX    PTRATIO         IMM        BPL      PRICE  \
# ...

# %%
# highway=df[((df['HIGHWAYCOUNT']==6) or (df['HIGHWAYCOUNT']==7) or (df['HIGHWAYCOUNT']==8))]

# %%
df['CATEGORY']=df['PRICE'].apply(lambda x: 1 if x<10 else 2 if 10<=x<20 else 3 if 20<=x<30 else 4 if 30<=x<40 else 5 if x>=40 else None)

# %%
df['CATEGORY'].value_counts()
df
# Out:
#            CRIM         ZN      INDUS  POLINDEX   RM    AGE        DIS  \
# 0      1.026769   1.429034   7.851300  1.134216  6.0   42.0   5.251911
# 1      0.848089   0.255543   6.263434  1.245993  7.0   63.0   4.305546
# 2     10.925905   0.441022  18.322960  2.824833  8.0   -2.0   2.409495
# 3      0.559027   1.041175  11.114920  0.794952  6.0    9.0   6.898669
# 4      0.905063  81.167963   3.673369  1.029030  8.0   20.0  10.246463
# ...         ...        ...        ...       ...  ...    ...        ...
# 3995   4.366543   1.159592  22.230240  1.146936  6.0   96.0   2.332414
# 3996   9.132894   0.294115  18.741019  0.876901  6.0  100.0   2.509486
# 3997   0.859468  21.201881   4.098201  1.142168  7.0  102.0   2.187747
# 3998   0.587681  45.399856   3.706238  1.719303  8.0   22.0   7.631113
# 3999   5.143827   0.000920  18.599543  0.864198  7.0   89.0   3.720523
#
#       HIGHWAYCOUNT         TAX    PTRATIO         IMM        BPL      PRICE  \
# ...

# %%
import numpy as np
df[['RIVERSIDE','AGE','RM']]=df[['RIVERSIDE','AGE','RM']].fillna(np.nan)

# %%
X=df.drop('PRICE',axis=1)
y=df['PRICE']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
X_train.shape
# Out:
# (2800, 14)

# %%
# Step 1
df
# Out:
#            CRIM         ZN      INDUS  POLINDEX   RM    AGE        DIS  \
# 0      1.026769   1.429034   7.851300  1.134216  6.0   42.0   5.251911
# 1      0.848089   0.255543   6.263434  1.245993  7.0   63.0   4.305546
# 2     10.925905   0.441022  18.322960  2.824833  8.0   -2.0   2.409495
# 3      0.559027   1.041175  11.114920  0.794952  6.0    9.0   6.898669
# 4      0.905063  81.167963   3.673369  1.029030  8.0   20.0  10.246463
# ...         ...        ...        ...       ...  ...    ...        ...
# 3995   4.366543   1.159592  22.230240  1.146936  6.0   96.0   2.332414
# 3996   9.132894   0.294115  18.741019  0.876901  6.0  100.0   2.509486
# 3997   0.859468  21.201881   4.098201  1.142168  7.0  102.0   2.187747
# 3998   0.587681  45.399856   3.706238  1.719303  8.0   22.0   7.631113
# 3999   5.143827   0.000920  18.599543  0.864198  7.0   89.0   3.720523
#
#       HIGHWAYCOUNT         TAX    PTRATIO         IMM        BPL      PRICE  \
# ...

# %%
df=df.drop('CATEGORY',axis=1)
df
# Out:
#            CRIM         ZN      INDUS  POLINDEX   RM    AGE        DIS  \
# 0      1.026769   1.429034   7.851300  1.134216  6.0   42.0   5.251911
# 1      0.848089   0.255543   6.263434  1.245993  7.0   63.0   4.305546
# 2     10.925905   0.441022  18.322960  2.824833  8.0   -2.0   2.409495
# 3      0.559027   1.041175  11.114920  0.794952  6.0    9.0   6.898669
# 4      0.905063  81.167963   3.673369  1.029030  8.0   20.0  10.246463
# ...         ...        ...        ...       ...  ...    ...        ...
# 3995   4.366543   1.159592  22.230240  1.146936  6.0   96.0   2.332414
# 3996   9.132894   0.294115  18.741019  0.876901  6.0  100.0   2.509486
# 3997   0.859468  21.201881   4.098201  1.142168  7.0  102.0   2.187747
# 3998   0.587681  45.399856   3.706238  1.719303  8.0   22.0   7.631113
# 3999   5.143827   0.000920  18.599543  0.864198  7.0   89.0   3.720523
#
#       HIGHWAYCOUNT         TAX    PTRATIO         IMM        BPL      PRICE  \
# ...

# %%
df['RIVERSIDE']=df['RIVERSIDE'].fillna(df['RIVERSIDE'].mode()[0])
df['AGE']=df['AGE'].fillna(df['AGE'].mean())
df['RM']=df['RM'].fillna(df['RM'].median())

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train[['CRIM', 'ZN','POLINDEX', 'RM', 'AGE', 'DIS', 'HIGHWAYCOUNT',
       'TAX', 'PTRATIO', 'IMM', 'BPL']]=scaler.fit_transform(X_train[['CRIM', 'ZN','POLINDEX', 'RM', 'AGE', 'DIS', 'HIGHWAYCOUNT',
       'TAX', 'PTRATIO', 'IMM', 'BPL']])

# %%
from sklearn.preprocessing import OneHotEncoder
one=OneHotEncoder()
encoded=one.fit_transform(X_train[['RIVERSIDE','INDUS']])

# %%
encoded.shape
# Out:
# (2800, 2803)
